# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading mandrill image
img_raw = cv2.imread('image.jpg')
type(img_raw)
# Out:
# numpy.ndarray

# %%
img_raw.shape
# Out:
# (224, 225, 3)

# %%
plt.imshow(img_raw[0:200][0:150][0:200])

# %%
# BGR, matplotlib, on the other hand, follows the order of RGB
plt.imshow(img_raw)

# %%
# fix
img = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
image_blank = np.zeros(shape=(512, 512, 3),dtype=np.int16)
plt.imshow(image_blank)

# %%
# draw shapes on image, cv2.shape(line, rectangle etc)(image,Pt1,Pt2,color,thickness)
line_red = cv2.line(img, (0,0), (511, 511), (255, 122, 0 ), 5)
plt.imshow(line_red)

# %%
line_green = cv2.line(img, (0, 200), (200, 0), (0, 255, 0), 5)
plt.imshow(line_green)

# %%
circle_blue = cv2.circle(img,(221,63), 63, (0,0,255), -1) # -1 corresponds to a filled circle
plt.imshow(circle_blue)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
text = cv2.putText(img,'OpenCV',(10,100), font, 3,(255,255,255),2,cv2.LINE_AA)
plt.imshow(text)

# %%
#Loading the image to be tested
test_image = cv2.imread('facial_image.jpg')
#Converting to grayscale
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
plt.imshow(test_image_gray)

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
haar_cascade_face = cv2.CascadeClassifier('haarcascade/haarcascade_frontalface_default.xml')
haar_cascade_face
# Out:
# <CascadeClassifier 160D6490>

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-22-634966c754f8> in <module>
# ----> 1 faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);
#       2
#       3 # Let us print the no. of faces found
#       4 print('Faces found: ', len(faces_rects))
#
# error: OpenCV(4.1.1) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'
